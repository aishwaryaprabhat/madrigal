# %% [markdown]
# ## Verify connection to Kubeflow Pipelines
# In my case, I used `kubectl -n kubeflow port-forward svc/ml-pipeline 8888` to port-forward to KFP host running on my microk8s cluster

# %%
import kfp

KFP_HOST = "http://localhost:8888"  # Replace with the actual port if different
client = kfp.Client(host=KFP_HOST)

# %%
client.list_runs()
# Out:
# {'next_page_token': None,
#  'runs': [{'created_at': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#            'description': None,
#            'display_name': 'Run of [Tutorial] Data passing in python '
#                            'components (c2b51)',
#            'error': None,
#            'experiment_id': 'fefd5bf7-1249-4290-ae93-55d572d49c3c',
#            'finished_at': datetime.datetime(2025, 1, 21, 11, 7, 5, tzinfo=tzlocal()),
#            'pipeline_spec': None,
#            'pipeline_version_id': None,
#            'pipeline_version_reference': {'pipeline_id': '6aa145d8-4b73-4b43-99c1-a790d29d9e2a',
#                                           'pipeline_version_id': '0db47dec-4ade-4239-a84a-9f94ad8639a6'},
#            'recurring_run_id': None,
#            'run_details': {'pipeline_context_id': None,
#                            'pipeline_run_context_id': None,
#                            'task_details': [{'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-1664218411',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'root-driver',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 4, 52, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'PENDING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 4, 36, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 2, tzinfo=tzlocal())}],
#                                              'task_id': 'f425bac8-7ebf-4cce-9197-29410d191091'},
#                                             {'child_tasks': None,
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 5, 49, tzinfo=tzlocal()),
#                                              'display_name': None,
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 9, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': '2',
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 5, 49, tzinfo=tzlocal()),
#                                              'state': None,
#                                              'state_history': None,
#                                              'task_id': 'd6056066-0f23-417a-85d4-afdc5b924d20'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-1224663975',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'train-driver',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 25, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 6, 20, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'PENDING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 21, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 31, tzinfo=tzlocal())}],
#                                              'task_id': 'c73d39ff-402f-4e86-9e75-4d30c5b2923d'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-3999247014',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'train',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 7, 5, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 6, 30, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 31, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 7, 7, tzinfo=tzlocal())}],
#                                              'task_id': 'bd34b62d-3f8e-42a6-a4e3-097f2763d03a'},
#                                             {'child_tasks': None,
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'executor',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 56, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 6, 30, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'PENDING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 31, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 41, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 7, 7, tzinfo=tzlocal())}],
#                                              'task_id': '991b0fa1-487f-49f9-9db3-15e750034ba3'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-2728139648',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'executor',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 10, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 5, 11, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'PENDING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 12, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 21, tzinfo=tzlocal())}],
#                                              'task_id': '8df6a26e-8180-4c59-ade5-61a27952b7f4'},
#                                             {'child_tasks': None,
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 6, 34, tzinfo=tzlocal()),
#                                              'display_name': None,
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 54, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': '3',
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 6, 34, tzinfo=tzlocal()),
#                                              'state': None,
#                                              'state_history': None,
#                                              'task_id': '8d76234f-5555-498f-a39d-53078502ffed'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-347795814',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'root',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 7, 5, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 5, 1, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 2, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 7, 7, tzinfo=tzlocal())}],
#                                              'task_id': '655eee3e-7b26-49e7-aabb-ce8433ecd9f3'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-4283148592',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'preprocess',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 6, 20, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 5, 11, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 12, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 6, 21, tzinfo=tzlocal())}],
#                                              'task_id': '2ea690f4-7021-4838-a297-b664ea7f93b6'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-3399620485',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'preprocess-driver',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 5, 5, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 5, 1, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'PENDING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 2, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 5, 12, tzinfo=tzlocal())}],
#                                              'task_id': '17e99b81-7bf4-4076-9e8c-77303802df1e'},
#                                             {'child_tasks': [{'pod_name': 'tutorial-data-passing-295z8-3478645516',
#                                                               'task_id': None}],
#                                              'create_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'display_name': 'tutorial-data-passing-295z8',
#                                              'end_time': datetime.datetime(2025, 1, 21, 11, 7, 5, tzinfo=tzlocal()),
#                                              'error': None,
#                                              'execution_id': None,
#                                              'executor_detail': None,
#                                              'inputs': None,
#                                              'outputs': None,
#                                              'parent_task_id': None,
#                                              'pod_name': None,
#                                              'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#                                              'start_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#                                              'state': 'SUCCEEDED',
#                                              'state_history': [{'error': None,
#                                                                 'state': 'RUNNING',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 4, 36, tzinfo=tzlocal())},
#                                                                {'error': None,
#                                                                 'state': 'SUCCEEDED',
#                                                                 'update_time': datetime.datetime(2025, 1, 21, 11, 7, 7, tzinfo=tzlocal())}],
#                                              'task_id': '07ac2719-a7a1-4130-8f0c-a3c7a06f5a4a'}]},
#            'run_id': 'affae618-cd21-489f-9ac0-ad159d547e2a',
#            'runtime_config': None,
#            'scheduled_at': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal()),
#            'service_account': 'pipeline-runner',
#            'state': 'SUCCEEDED',
#            'state_history': [{'error': None,
#                               'state': 'PENDING',
#                               'update_time': datetime.datetime(2025, 1, 21, 11, 4, 35, tzinfo=tzlocal())},
#                              {'error': None,
#                               'state': 'RUNNING',
#                               'update_time': datetime.datetime(2025, 1, 21, 11, 4, 36, tzinfo=tzlocal())},
#                              {'error': None,
#                               'state': 'SUCCEEDED',
#                               'update_time': datetime.datetime(2025, 1, 21, 11, 7, 6, tzinfo=tzlocal())}],
#            'storage_state': 'AVAILABLE'}],
#  'total_size': 1}

# %% [markdown]
# ## Verify connection to Ray Cluster

# %%
import ray

RAY_CLUSTER_ADDRESS = "ray://localhost:10001"  # Adjust port if necessary
ray.init(address=RAY_CLUSTER_ADDRESS)
# Out:
# 2025-01-21 12:36:28,595	INFO client_builder.py:244 -- Passing the following kwargs to ray.init() on the server: log_to_driver
# SIGTERM handler is not set because current thread is not the main thread.
# ClientContext(dashboard_url='10.1.248.48:8265', python_version='3.11.11', ray_version='2.40.0', ray_commit='160e35738334959a26b1a8397f0ea1dcbe9c271f', _num_clients=1, _context_to_restore=<ray.util.client._ClientContext object at 0x7d569fa79390>, protocol_version=None)
